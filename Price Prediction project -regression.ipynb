# %% [markdown]
# # Price Prediction using Regression

# %% [markdown]
# This is a tickets pricing monitoring system. It scrapes tickets pricing data periodically and stores it in a database. Ticket pricing changes based on demand and time, and there can be significant difference in price. We are creating this product mainly with ourselves in mind. Users can set up alarms using an email, choosing an origin and destination (cities), time (date and hour range picker) choosing a price reduction over mean price, etc.

# %% [markdown]
# **Following is the description for columns in the dataset**<br>
# - insert_date: date and time when the price was collected and written in the database<br>
# - origin: origin city <br>
# - destination: destination city <br>
# - start_date: train departure time<br>
# - end_date: train arrival time<br>
# - train_type: train service name<br>
# - price: price<br>
# - train_class: ticket class, tourist, business, etc.<br>
# - fare: ticket fare, round trip, etc <br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set()

# %% [markdown]
# #### **Task 1: Import Dataset and create a copy of that dataset**

# %%
#write code here
data = pd.read_csv('data1.csv')
df = data.copy()

# %% [markdown]
# #### **Task 2: Display first five rows**

# %%
#write code here
df.head()
# Out:
#    Unnamed: 0          insert_date      origin destination  \
# 0         702  2019-04-19 05:37:35  PONFERRADA      MADRID
# 1         703  2019-04-19 05:37:35  PONFERRADA      MADRID
# 2         704  2019-04-19 05:37:35  PONFERRADA      MADRID
# 3         705  2019-04-19 05:37:35  PONFERRADA      MADRID
# 4         706  2019-04-19 05:37:35  PONFERRADA      MADRID
#
#             start_date             end_date train_type  price  \
# 0  2019-06-02 15:00:00  2019-06-02 19:42:00     MD-AVE  59.50
# 1  2019-06-02 17:15:00  2019-06-02 23:03:00     MD-AVE  34.65
# 2  2019-06-02 17:15:00  2019-06-02 23:10:00      MD-LD  39.95
# 3  2019-06-02 17:15:00  2019-06-02 22:14:00     MD-AVE  40.60
# 4  2019-06-02 18:55:00  2019-06-02 23:03:00      ALVIA  27.90
#
#           train_class      fare
# 0  Turista con enlace  Flexible
# 1  Turista con enlace   Promo +
# 2  Turista con enlace   Promo +
# 3  Turista con enlace   Promo +
# 4             Turista     Promo

# %% [markdown]
# #### **Task 3: Drop 'unnamed: 0' column**

# %%
#write code here
df.drop('Unnamed: 0',axis='columns',inplace=True)

# %% [markdown]
# #### **Task 4: Check the number of rows and columns**

# %%
#write code here
df.shape
# Out:
# (215909, 9)

# %% [markdown]
# #### **Task 5: Check data types of all columns**

# %%
#write code here
df.dtypes
# Out:
# insert_date     object
# origin          object
# destination     object
# start_date      object
# end_date        object
# train_type      object
# price          float64
# train_class     object
# fare            object
# dtype: object

# %% [markdown]
# #### **Task 6: Check summary statistics**

# %%
#write code here
df.describe()
# Out:
#                price
# count  202321.000000
# mean       56.723877
# std        25.531787
# min        16.600000
# 25%        28.350000
# 50%        53.400000
# 75%        76.300000
# max       206.800000

# %% [markdown]
# #### **Task 7: Check summary statistics of all columns, including object dataypes**

# %%
df.describe(include='all')
# Out:
#                 insert_date  origin destination           start_date  \
# count                215909  215909      215909               215909
# unique                30543       5           5                 2231
# top     2019-05-09 15:02:02  MADRID      MADRID  2019-06-02 17:30:00
# freq                     90  110440      105469                 2089
# mean                    NaN     NaN         NaN                  NaN
# std                     NaN     NaN         NaN                  NaN
# min                     NaN     NaN         NaN                  NaN
# 25%                     NaN     NaN         NaN                  NaN
# 50%                     NaN     NaN         NaN                  NaN
# 75%                     NaN     NaN         NaN                  NaN
# max                     NaN     NaN         NaN                  NaN
#
#                    end_date train_type          price train_class    fare
# ...

# %% [markdown]
# **Question: Explain the summary statistics for the above data set**

# %% [markdown]
# **Answer:**

# %% [markdown]
# #### **Task 8: Check null values in dataset**

# %%
#write code here
df.isnull().sum()
# Out:
# insert_date        0
# origin             0
# destination        0
# start_date         0
# end_date           0
# train_type         0
# price          13588
# train_class      643
# fare             643
# dtype: int64

# %% [markdown]
# #### **Task 9: Fill the Null values in the 'price' column.**<br>
# *Hint: Take mean*

# %%
#write code here
df['price'].fillna(df['price'].mean(),inplace=True)

# %% [markdown]
# #### **Task 10: Drop the rows containing Null values in the attributes train_class and fare**

# %%
#write code here
df.dropna(subset=['fare','train_class'],inplace=True)

# %% [markdown]
# #### **Task 11: Drop 'insert_date'**

# %%
#write code here
df.drop('insert_date',axis='columns',inplace=True)

# %% [markdown]
# **Check null values again in dataset**

# %%
#write code here
df.isnull().sum()
# Out:
# origin         0
# destination    0
# start_date     0
# end_date       0
# train_type     0
# price          0
# train_class    0
# fare           0
# dtype: int64

# %%
df.shape
# Out:
# (215266, 8)

# %% [markdown]
# #### **Task 12: Plot number of people boarding from different stations**

# %%
#write code here
sns.countplot(x='origin',data=df)
plt.xlabel('Boarding Cities')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %% [markdown]
# **Question: What insights do you get from the above plot?**

# %% [markdown]
# **Answer:** From the above plot we can observe most of the pessengers were boarded from MADRID then from Barcelona and then comes Valencia Sevilla and at last Ponferrada

# %% [markdown]
# #### **Task 13: Plot number of people for the destination stations**

# %%
sns.countplot(x='destination',data=df)
plt.xlabel('Destination stations')
plt.ylabel('Number of People')
# Out:
# Text(0, 0.5, 'Number of People')

# %% [markdown]
# **Question: What insights do you get from the above graph?**

# %% [markdown]
# **Answer:** Most of the people were dropped off to Madrid and the least of them were dropped at Ponferrada.

# %% [markdown]
# #### **Task 14: Plot different types of train that runs in Spain**

# %%
#write code here
plt.figure(figsize=(16,6))
sns.countplot(x='train_type',data=df)
plt.xlabel('Type to Trains')
# Out:
# Text(0.5, 0, 'Type to Trains')

# %% [markdown]
# **Question: Which train runs the maximum in number as compared to other train types?**

# %% [markdown]
# **Answer:** From the above plot we observed that AVE runs maximum in number as compared to other train types.

# %% [markdown]
# #### **Task 15: Plot number of trains of different class**

# %%
#write code here
sns.countplot(x='train_class',data=df)
plt.xlabel('Type to Trains')
# Out:
# Text(0.5, 0, 'Type to Trains')

# %% [markdown]
# **Question: Which the most common train class for traveling among people in general?**

# %% [markdown]
# **Answer:**
# Truista is the most common train class for traveling among the people.

# %% [markdown]
# #### **Task 16: Plot number of tickets bought from each category**

# %%
#write code here
sns.countplot(x='fare',data=df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='count'>

# %% [markdown]
# **Question: Which the most common tickets are bought?**

# %% [markdown]
# **Answer:**  Promo is the most common type to ticket bought by the among people.

# %% [markdown]
# #### **Task 17: Plot distribution of the ticket prices**

# %%
#write code here
plt.figure(figsize=(16,6))
sns.distplot(x=df.price)
# Out:
# D:\data science\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# **Question: What readings can you get from the above plot?**

# %% [markdown]
# **Answer:** From the above plot we can observe that most of the ticket bought where in the price of 30-35.

# %% [markdown]
# ###### **Task 18: Show train_class vs price through boxplot**

# %%
#write code here
sns.boxplot(x='train_class',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='train_class', ylabel='price'>

# %% [markdown]
# **Question: What pricing trends can you find out by looking at the plot above?**

# %% [markdown]
# **Answer:** From the above plot we can observe Turista Plus has the highest median price. Turista has highest IQR while Cama Turista has lowest IQR for the prices wrt to train classes.

# %% [markdown]
# #### **Task 19: Show train_type vs price through boxplot**

# %%
#write code here
plt.figure(figsize=(17,6))
sns.boxplot(x='train_type',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='price'>

# %% [markdown]
# **Question: Which type of trains cost more as compared to others?**

# %% [markdown]
# **Answer:** AVE type of trains could cost the most beacuse it has the highest median price.

# %% [markdown]
# ## Feature Engineering

# %%
df = df.reset_index()

# %% [markdown]
# **Finding the travel time between the place of origin and destination**<br>
# We need to find out the travel time for each entry which can be obtained from the 'start_date' and 'end_date' column. Also if you see, these columns are in object type therefore datetimeFormat should be defined to perform the necessary operation of getting the required time.

# %% [markdown]
# **Import datetime library**

# %%
#write code here
import datetime

# %%
datetimeFormat = '%Y-%m-%d %H:%M:%S'
def fun(a,b):
    diff = datetime.datetime.strptime(b, datetimeFormat)- datetime.datetime.strptime(a, datetimeFormat)
    return(diff.seconds/3600.0)

# %%
df['travel_time_in_hrs'] = df.apply(lambda x:fun(x['start_date'],x['end_date']),axis=1)

# %% [markdown]
# #### **Task 20: Remove redundant features**

# %% [markdown]
# **You need to remove features that are giving the related values as  'travel_time_in_hrs'**<br>
# *Hint: Look for date related columns*

# %%
df.head()
# Out:
#    index      origin destination           start_date             end_date  \
# 0      0  PONFERRADA      MADRID  2019-06-02 15:00:00  2019-06-02 19:42:00
# 1      1  PONFERRADA      MADRID  2019-06-02 17:15:00  2019-06-02 23:03:00
# 2      2  PONFERRADA      MADRID  2019-06-02 17:15:00  2019-06-02 23:10:00
# 3      3  PONFERRADA      MADRID  2019-06-02 17:15:00  2019-06-02 22:14:00
# 4      4  PONFERRADA      MADRID  2019-06-02 18:55:00  2019-06-02 23:03:00
#
#   train_type  price         train_class      fare  travel_time_in_hrs
# 0     MD-AVE  59.50  Turista con enlace  Flexible            4.700000
# 1     MD-AVE  34.65  Turista con enlace   Promo +            5.800000
# 2      MD-LD  39.95  Turista con enlace   Promo +            5.916667
# 3     MD-AVE  40.60  Turista con enlace   Promo +            4.983333
# 4      ALVIA  27.90             Turista     Promo            4.133333

# %%
#write code here
df.drop(['start_date','end_date'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#    index      origin destination train_type  price         train_class  \
# 0      0  PONFERRADA      MADRID     MD-AVE  59.50  Turista con enlace
# 1      1  PONFERRADA      MADRID     MD-AVE  34.65  Turista con enlace
# 2      2  PONFERRADA      MADRID      MD-LD  39.95  Turista con enlace
# 3      3  PONFERRADA      MADRID     MD-AVE  40.60  Turista con enlace
# 4      4  PONFERRADA      MADRID      ALVIA  27.90             Turista
#
#        fare  travel_time_in_hrs
# 0  Flexible            4.700000
# 1   Promo +            5.800000
# 2   Promo +            5.916667
# 3   Promo +            4.983333
# 4     Promo            4.133333

# %% [markdown]
# We now need to find out the pricing from 'MADRID' to other destinations. We also need to find out time which each train requires for travelling.

# %% [markdown]
# ## **Travelling from MADRID to SEVILLA**

# %% [markdown]
# #### Task 21: Findout people travelling from MADRID to SEVILLA

# %%
#write code here
df1 = df[(df['origin']=='MADRID') & (df['destination']=='SEVILLA')]

# %% [markdown]
# #### Task 22: Make a plot for finding out travelling hours for each train type

# %%
#write code here
sns.barplot(data=df1,x='train_type',y='travel_time_in_hrs')
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='travel_time_in_hrs'>

# %% [markdown]
# #### **Task 23: Show train_type vs price through boxplot**

# %%
#write code here
sns.boxplot(x='train_type',y='price',data=df1)
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='price'>

# %% [markdown]
# ## **Travelling from MADRID to BARCELONA**

# %% [markdown]
# #### Task 24: Findout people travelling from MADRID to BARCELONA

# %%
#write code here
df1 = df[(df['origin']=='MADRID') & (df['destination']=='BARCELONA')]

# %% [markdown]
# #### Task 25: Make a plot for finding out travelling hours for each train type

# %%
#write code here
sns.barplot(data=df1,x='train_type',y='travel_time_in_hrs')
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='travel_time_in_hrs'>

# %% [markdown]
# #### **Task 26: Show train_type vs price through boxplot**

# %%
#write code here
sns.boxplot(x='train_type',y='price',data=df1)
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='price'>

# %% [markdown]
# ## **Travelling from MADRID to VALENCIA**

# %% [markdown]
# #### Task 27: Findout people travelling from MADRID to VALENCIA

# %%
#write code here
df1 = df[(df['origin']=='MADRID') & (df['destination']=='VALENCIA')]

# %% [markdown]
# #### Task 28: Make a plot for finding out travelling hours for each train type

# %%
#write code here
sns.barplot(data=df1,x='train_type',y='travel_time_in_hrs')
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='travel_time_in_hrs'>

# %% [markdown]
# #### **Task 29: Show train_type vs price through boxplot**

# %%
#write code here
sns.boxplot(x='train_type',y='price',data=df1)
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='price'>

# %% [markdown]
# ## **Travelling from MADRID to PONFERRADA**

# %% [markdown]
# #### Task 30: Findout people travelling from MADRID to PONFERRADA

# %%
#write code here
df1 = df[(df['origin']=='MADRID') & (df['destination']=='PONFERRADA')]

# %% [markdown]
# #### Task 31: Make a plot for finding out travelling hours for each train type

# %%
#write code here
plt.figure(figsize=(8,5))
sns.barplot(data=df1,x='train_type',y='travel_time_in_hrs')
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='travel_time_in_hrs'>

# %% [markdown]
# #### **Task 32: Show train_type vs price through boxplot**

# %%
#write code here
sns.boxplot(x='train_type',y='price',data=df1)
# Out:
# <AxesSubplot:xlabel='train_type', ylabel='price'>

# %% [markdown]
# # Applying Linear  Regression

# %% [markdown]
# #### Task 33: Import LabelEncoder library from sklearn

# %%
#write code here
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# **Data Encoding**

# %%
lab_en = LabelEncoder()
df.iloc[:,1] = lab_en.fit_transform(df.iloc[:,1])
df.iloc[:,2] = lab_en.fit_transform(df.iloc[:,2])
df.iloc[:,3] = lab_en.fit_transform(df.iloc[:,3])
df.iloc[:,5] = lab_en.fit_transform(df.iloc[:,5])
df.iloc[:,6] = lab_en.fit_transform(df.iloc[:,6])

# %%
df.head()
# Out:
#    index  origin  destination  train_type  price  train_class  fare  \
# 0      0       2            1          11  59.50            4     1
# 1      1       2            1          11  34.65            4     4
# 2      2       2            1          12  39.95            4     4
# 3      3       2            1          11  40.60            4     4
# 4      4       2            1           0  27.90            2     3
#
#    travel_time_in_hrs
# 0            4.700000
# 1            5.800000
# 2            5.916667
# 3            4.983333
# 4            4.133333

# %% [markdown]
# #### Task 34: Separate the dependant and independant variables

# %%
#write code here
X = df.drop('price',axis='columns')
Y = df[['price']]

# %% [markdown]
# #### Task 35: Import test_train_split from sklearn

# %%
#write code here
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Task 36:**Split the data into training and test set**

# %%
#write code here
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# #### Task 37: Import LinearRegression library from sklearn

# %%
#write code here
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Task 38: Make an object of LinearRegression( ) and train it using the training data set

# %%
#write code here
lr = LinearRegression()

# %%
#write code here
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Task 39: Find out the predictions using test data set.

# %%
#write code here
lr_predict = lr.predict(X_test)
lr_predict
# Out:
# array([[55.32812806],
#        [79.54730818],
#        [78.64922427],
#        ...,
#        [28.70247182],
#        [80.16183922],
#        [81.83009793]])

# %% [markdown]
# #### Task 40: Find out the predictions using training data set.

# %%
#write code here
lr_predict_train = lr.predict(X_train)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.7269299029186662

# %% [markdown]
# #### Task 41: Import r2_score library form sklearn

# %%
#write code here
from sklearn.metrics import r2_score

# %% [markdown]
# #### Task 42: Find out the R2 Score for test data and print it.

# %%
#write code here
lr_r2_test= r2_score(Y_test,lr_predict)

# %% [markdown]
# #### Task 43: Find out the R2 Score for training data and print it.

# %%
lr_r2_train = r2_score(Y_train,lr_predict_train)

# %% [markdown]
# Comaparing training and testing R2 scores

# %%
print('R2 score for Linear Regression Training Data is: ', lr_r2_train)
print('R2 score for Linear Regression Testing Data is: ', lr_r2_test)
# Out:
# R2 score for Linear Regression Training Data is:  0.7273849644779448
# R2 score for Linear Regression Testing Data is:  0.7269299029186662

# %% [markdown]
# # Applying Polynomial Regression

# %% [markdown]
# #### Task 44: Import PolynomialFeatures from sklearn

# %%
#write code here
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# #### Task 45: Make and object of default Polynomial Features

# %%
#write code here
poly_reg = PolynomialFeatures(degree=2)

# %% [markdown]
# #### Task 46: Transform the features to higher degree features.

# %%
#write code here
X_train_poly,X_test_poly = poly_reg.fit_transform(X_train),poly_reg.fit_transform(X_test)

# %%
X_train_poly.shape
# Out:
# (150686, 36)

# %% [markdown]
# #### Task 47: Fit the transformed features to Linear Regression

# %%
#write code here
poly_model = lr.fit(X_train_poly,Y_train)

# %% [markdown]
# #### Task 48: Find the predictions on the data set

# %%
#write code here
y_train_predicted,y_test_predict = poly_model.predict(X_train_poly),poly_model.predict(X_test_poly)

# %% [markdown]
# #### Task 49: Evaluate R2 score for training data set

# %%
#evaluating the model on training dataset
#write code here
r2_train = r2_score(Y_train,y_train_predicted)

# %% [markdown]
# #### Task 50: Evaluate R2 score for test data set

# %%
# evaluating the model on test dataset
#write code here
r2_test = r2_score(Y_test,y_test_predict)

# %% [markdown]
# Comaparing training and testing R2 scores

# %%
#write code here
print ('The r2 score for training set is: ',r2_train)
print ('The r2 score for testing set is: ',r2_test)
# Out:
# The r2 score for training set is:  0.8229847824677909
# The r2 score for testing set is:  0.8222576203102159

# %% [markdown]
# #### Task 51: Select the best model

# %% [markdown]
# **Question: Which model gives the best result for price prediction? Find out the complexity using R2 score and give your answer.**<br>
# *Hint: Use for loop for finding the best degree and model complexity for polynomial regression model*

# %%
#write code here
r2_train=[]
r2_test=[]
for i in range(1,6):
    poly_reg = PolynomialFeatures(degree=i)
    
    X_tr_poly,X_tst_poly = poly_reg.fit_transform(X_train),poly_reg.fit_transform(X_test)
    poly = LinearRegression()
    poly.fit(X_tr_poly, Y_train)
   
    y_tr_predicted,y_tst_predict = poly.predict(X_tr_poly),poly.predict(X_tst_poly)
    r2_train.append(r2_score(Y_train, y_tr_predicted))
    r2_test.append(r2_score(Y_test, y_tst_predict))
    
print ('R2 Train', r2_train)
print ('R2 Test', r2_test)
# Out:
# R2 Train [0.7273849644779448, 0.8229847824677909, 0.7963576690039242, 0.7080936373356355, 0.6034406385072675]
# R2 Test [0.7269299029186662, 0.8222576203102159, 0.7969577010090076, 0.7071390849126833, 0.6014686087011036]

# %% [markdown]
# #### Plotting the model

# %%
plt.figure(figsize=(18,5))
sns.set_context('poster')
plt.subplot(1,2,1)
sns.lineplot(x=list(range(1,6)), y=r2_train, label='Training');
plt.subplot(1,2,2)
sns.lineplot(x=list(range(1,6)), y=r2_test, label='Testing');

# %% [markdown]
# **Answer** After evaluating various models for price prediction it has been determined that the model with the best performance, as measured by the R-squared (R2) score, is a polynomial regression model with degree 2. Graph shows the best fit model is also at degree = 2. So overall we can say that our model's relationship between the predictors and the target variable exhibits a non-linear pattern that a simple linear model couldn't capture properly.
